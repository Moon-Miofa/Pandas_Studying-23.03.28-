# %% [markdown]
# #10. 데이터 확인

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
drive_path = ('/gdrive/My Drive/colaboratory/')

# %%
import pandas as pd

# %%
df = pd.read_excel(drive_path + 'score.xlsx', index_col='지원번호')

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        sw특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
"""
데이터 분석 : 데이터 요약 작업
표에서 나타나는 데이터는, 가시적이지 않다. -> 이것을 요약해서 분포 등을 시각적으로 볼 수 있어야지
통계 : 수많은 데이터에 대한 해석
코드 : 데이터 제어
"""
# Out:
# '\n데이터 분석 : 데이터 요약 작업\n표에서 나타나는 데이터는, 가시적이지 않다. -> 이것을 요약해서 분포 등을 시각적으로 볼 수 있어야지\n통계 : 수많은 데이터에 대한 해석\n코드 : 데이터 제어\n'

# %% [markdown]
# ##데이터프레임 요약 통계

# %%
"""
count : 데이터 수 (index 수)
mean : 평군값
std : 표준편치
min : 최소값
25% ~ 75% : 해당 %에 해당하는 값
max : 최댓값
** NaN : 데이터가 비어있음.
"""
df.describe() #숫자 데이터 열에 대해 요약 통계를 나타냄
# Out:
#                 키          국어          영어          수학         과학         사회
# count    8.000000    8.000000    8.000000    8.000000   8.000000   8.000000
# mean   188.000000   62.500000   65.625000   66.250000  70.000000  60.625000
# std      9.985704   29.519969   26.917533   30.325614  23.754699  32.120032
# min    168.000000   15.000000   20.000000   10.000000  35.000000  10.000000
# 25%    186.250000   40.000000   53.750000   48.750000  51.250000  32.500000
# 50%    188.000000   67.500000   70.000000   70.000000  77.500000  77.500000
# 75%    191.750000   82.500000   85.000000   91.250000  87.500000  81.250000
# max    202.000000  100.000000  100.000000  100.000000  95.000000  95.000000

# %% [markdown]
# ##데이터프레임 구조 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1번 to 8번
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      8 non-null      object
#  1   학교      8 non-null      object
#  2   키       8 non-null      int64
#  3   국어      8 non-null      int64
#  4   영어      8 non-null      int64
#  5   수학      8 non-null      int64
#  6   과학      8 non-null      int64
#  7   사회      8 non-null      int64
#  8   sw특기    6 non-null      object
# dtypes: int64(6), object(3)
# memory usage: 640.0+ bytes

# %%
#행, 열을 튜플로 출력함
df.shape
# Out:
# (8, 9)

# %%
df.shape[0]
# Out:
# 8

# %%
df.shape[1]
# Out:
# 9

# %% [markdown]
# ##데이터 미리보기 (head, tail)

# %%
df.head() #기본 5줄을 미리보기
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        sw특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [이름, 학교, 키, 국어, 영어, 수학, 과학, 사회, sw특기]
# Index: []

# %%
df.tail() #끝에서 5줄을 출력
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    sw특기
# 지원번호
# 4번    서태웅  북산고  187   40   60  70  75  80     NaN
# 5번    강백호  북산고  188   15   20  10  35  10     NaN
# 6번    변덕규  능남고  202   80  100  95  85  80       C
# 7번    황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.tail(6)
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회        sw특기
# 지원번호
# 3번    송태섭  북산고  168   80   75  70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60  70  75  80         NaN
# 5번    강백호  북산고  188   15   20  10  35  10         NaN
# 6번    변덕규  능남고  202   80  100  95  85  80           C
# 7번    황태산  능남고  188   55   65  45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95          C#

# %% [markdown]
# ## 데이터프레임 인덱스 확인 (행 구분)

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %% [markdown]
# ##데이터프레임 열 이름 확인

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'sw특기'], dtype='object')

# %%
df.columns[0]
# Out:
# '이름'

# %%
df.columns[-1]
# Out:
# 'sw특기'

# %%
df.columns[0:4]
# Out:
# Index(['이름', '학교', '키', '국어'], dtype='object')

# %% [markdown]
# ## 데이터프레임 데이터 확인 (인덱스를 제외한)

# %%
df.values
# Out:
# array([['채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'],
#        ['정대만', '북산고', 184, 40, 35, 50, 55, 25, 'Java'],
#        ['송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C'],
#        ['황태산', '능남고', 188, 55, 65, 45, 40, 35, 'PYTHON'],
#        ['윤대협', '능남고', 190, 100, 85, 90, 95, 95, 'C#']], dtype=object)

# %%
df.values[0]
# Out:
# array(['채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'], dtype=object)

# %%
df.values[0][0]
# Out:
# '채치수'

# %% [markdown]
# ## 시리즈 확인 (한줄 확인)

# %%
df['키']
# Out:
# 지원번호
# 1번    197
# 2번    184
# 3번    168
# 4번    187
# 5번    188
# 6번    202
# 7번    188
# 8번    190
# Name: 키, dtype: int64

# %%
df['키'].describe()
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].min()
# Out:
# 168

# %%
df['키'].max()
# Out:
# 202

# %%
df['키'].mean()
# Out:
# 188.0

# %%
df['키'].sum()
# Out:
# 1504

# %%
df['키'].count()
# Out:
# 8

# %%
df['키'].std()
# Out:
# 9.98570406702931

# %% [markdown]
# 평균, 표준편차, 최소값, 최대값,
#
# 25% 50% 75% : 사분위수
#
# => 분포를 나타낸다

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        sw특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.describe(include = 'all')
# Out:
#          이름   학교           키          국어          영어          수학         과학  \
# count     8    8    8.000000    8.000000    8.000000    8.000000   8.000000
# unique    8    2         NaN         NaN         NaN         NaN        NaN
# top     채치수  북산고         NaN         NaN         NaN         NaN        NaN
# freq      1    5         NaN         NaN         NaN         NaN        NaN
# mean    NaN  NaN  188.000000   62.500000   65.625000   66.250000  70.000000
# std     NaN  NaN    9.985704   29.519969   26.917533   30.325614  23.754699
# min     NaN  NaN  168.000000   15.000000   20.000000   10.000000  35.000000
# 25%     NaN  NaN  186.250000   40.000000   53.750000   48.750000  51.250000
# 50%     NaN  NaN  188.000000   67.500000   70.000000   70.000000  77.500000
# 75%     NaN  NaN  191.750000   82.500000   85.000000   91.250000  87.500000
# max     NaN  NaN  202.000000  100.000000  100.000000  100.000000  95.000000
#
#                사회    sw특기
# count    8.000000       6
# ...

# %%
df['학교'].unique() #종류 확인
# Out:
# array(['북산고', '능남고'], dtype=object)

# %%
df['학교'].nunique() #종류 갯수
# Out:
# 2

# %%
df['학교'].count()
# Out:
# 8

# %%
df['학교'].value_counts()
# Out:
# 북산고    5
# 능남고    3
# Name: 학교, dtype: int64

# %%
df['학교'].value_counts()['북산고']
# Out:
# 5

# %%
df['학교'].value_counts()['능남고']
# Out:
# 3

# %%
df_학교범주 = df['학교'].value_counts()

# %%
df_학교범주
# Out:
# 북산고    5
# 능남고    3
# Name: 학교, dtype: int64

# %%
df_학교범주['북산고']
# Out:
# 5
